# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Load Dataset

goodreads = pd.read_csv('C:/Users/HP WORLD/Desktop/Goodreads/books.csv')

goodreads2 = pd.read_csv('C:/Users/HP WORLD/Desktop/Goodreads/Books2.csv')

# %%
# Dataset 1

goodreads.head()
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince Harry P...
# 1       2  Harry Potter and the Order of the Phoenix Harr...
# 2       4  Harry Potter and the Chamber of Secrets Harry ...
# 3       5  Harry Potter and the Prisoner of Azkaban Harry...
# 4       8  Harry Potter Boxed Set  Books 1-5 Harry Potter...
#
#                       authors average_rating        isbn       isbn13  \
# 0  J.K. Rowling/Mary GrandPré           4.57   439785960  9.78044E+12
# 1  J.K. Rowling/Mary GrandPré           4.49   439358078  9.78044E+12
# 2                J.K. Rowling           4.42   439554896  9.78044E+12
# 3  J.K. Rowling/Mary GrandPré           4.56  043965548X  9.78044E+12
# 4  J.K. Rowling/Mary GrandPré           4.78   439682584  9.78044E+12
#
#   language_code   num_pages  ratings_count  text_reviews_count  \
# 0           eng         652        2095690               27591
# ...

# %%
# Dataset 2

goodreads2.head()
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince Harry P...
# 1       2  Harry Potter and the Order of the Phoenix Harr...
# 2       4  Harry Potter and the Chamber of Secrets Harry ...
# 3       5  Harry Potter and the Prisoner of Azkaban Harry...
# 4       8  Harry Potter Boxed Set  Books 1-5 Harry Potter...
#
#                        authors average_rating
# 0  J.K. Rowling/Mary GrandPrÃ©           4.57
# 1  J.K. Rowling/Mary GrandPrÃ©           4.49
# 2                 J.K. Rowling           4.42
# 3  J.K. Rowling/Mary GrandPrÃ©           4.56
# 4  J.K. Rowling/Mary GrandPrÃ©           4.78

# %%
goodreads.shape
# Out:
# (11127, 13)

# %%
# Column Names Consistent (Rename Columns)

goodreads.rename(columns = {'bookID':'BookID','title':'Title','authors':'Authors'}, inplace=True)

# %%
goodreads.head()
# Out:
#    BookID                                              Title  \
# 0       1  Harry Potter and the Half-Blood Prince Harry P...
# 1       2  Harry Potter and the Order of the Phoenix Harr...
# 2       4  Harry Potter and the Chamber of Secrets Harry ...
# 3       5  Harry Potter and the Prisoner of Azkaban Harry...
# 4       8  Harry Potter Boxed Set  Books 1-5 Harry Potter...
#
#                       Authors average_rating        isbn       isbn13  \
# 0  J.K. Rowling/Mary GrandPré           4.57   439785960  9.78044E+12
# 1  J.K. Rowling/Mary GrandPré           4.49   439358078  9.78044E+12
# 2                J.K. Rowling           4.42   439554896  9.78044E+12
# 3  J.K. Rowling/Mary GrandPré           4.56  043965548X  9.78044E+12
# 4  J.K. Rowling/Mary GrandPré           4.78   439682584  9.78044E+12
#
#   language_code   num_pages  ratings_count  text_reviews_count  \
# 0           eng         652        2095690               27591
# ...

# %%
goodreads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11127 entries, 0 to 11126
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   BookID              11127 non-null  int64
#  1   Title               11127 non-null  object
#  2   Authors             11127 non-null  object
#  3   average_rating      11127 non-null  object
#  4   isbn                11127 non-null  object
#  5   isbn13              11127 non-null  object
#  6   language_code       11127 non-null  object
#  7     num_pages         11127 non-null  object
#  8   ratings_count       11127 non-null  int64
#  9   text_reviews_count  11127 non-null  int64
#  10  publication_date    11127 non-null  object
#  11  publisher           11127 non-null  object
#  12  Column1             4 non-null      object
# dtypes: int64(3), object(10)
# memory usage: 1.1+ MB

# %%
goodreads.describe()
# Out:
#              BookID  ratings_count  text_reviews_count
# count  11127.000000   1.112700e+04        11127.000000
# mean   21310.938887   1.793649e+04          541.864474
# std    13093.358023   1.124794e+05         2576.174610
# min        1.000000   0.000000e+00            0.000000
# 25%    10287.000000   1.040000e+02            9.000000
# 50%    20287.000000   7.450000e+02           47.000000
# 75%    32104.500000   4.993500e+03          237.500000
# max    45641.000000   4.597666e+06        94265.000000

# %%
# Check NULL Values

nan_values = goodreads.isna()
nan_columns = nan_values.any()
nan_columns
# Out:
# BookID                False
# Title                 False
# Authors               False
# average_rating        False
# isbn                  False
# isbn13                False
# language_code         False
#   num_pages           False
# ratings_count         False
# text_reviews_count    False
# publication_date      False
# publisher             False
# Column1                True
# dtype: bool

# %%
goodreads.isnull().sum()
# Out:
# BookID                    0
# Title                     0
# Authors                   0
# average_rating            0
# isbn                      0
# isbn13                    0
# language_code             0
#   num_pages               0
# ratings_count             0
# text_reviews_count        0
# publication_date          0
# publisher                 0
# Column1               11123
# dtype: int64

# %%
# Publisher Details (Sort)

goodreads.query('publisher =="Broadway Books"').head(5)
# Out:
#     BookID                                              Title      Authors  \
# 12      21               A Short History of Nearly Everything  Bill Bryson
# 13      22                        Bill Bryson's African Diary  Bill Bryson
# 14      23  Bryson's Dictionary of Troublesome Words: A Wr...  Bill Bryson
# 15      24                             In a Sunburned Country  Bill Bryson
# 16      25  I'm a Stranger Here Myself: Notes on Returning...  Bill Bryson
#
#    average_rating        isbn       isbn13 language_code   num_pages  \
# 12           4.21  076790818X  9.78077E+12           eng         544
# 13           3.44   767915062  9.78077E+12           eng          55
# 14           3.87   767910435  9.78077E+12           eng         256
# 15           4.07   767903862  9.78077E+12           eng         335
# 16            3.9  076790382X  9.78077E+12           eng         304
#
#     ratings_count  text_reviews_count publication_date       publisher Column1
# ...

# %%
# Author Details (Sort)

goodreads.query('Authors =="Bill Bryson"').head(3)
# Out:
#     BookID                                              Title      Authors  \
# 12      21               A Short History of Nearly Everything  Bill Bryson
# 13      22                        Bill Bryson's African Diary  Bill Bryson
# 14      23  Bryson's Dictionary of Troublesome Words: A Wr...  Bill Bryson
#
#    average_rating        isbn       isbn13 language_code   num_pages  \
# 12           4.21  076790818X  9.78077E+12           eng         544
# 13           3.44   767915062  9.78077E+12           eng          55
# 14           3.87   767910435  9.78077E+12           eng         256
#
#     ratings_count  text_reviews_count publication_date       publisher Column1
# 12         248558                9396        9/14/2004  Broadway Books     NaN
# 13           7270                 499       12-03-2002  Broadway Books     NaN
# 14           2088                 131        9/14/2004  Broadway Books     NaN

# %%
# Top 10 Books

top_10_books = goodreads.sort_values(by ='average_rating',ascending = False).head(10)
top_10_books
# Out:
#       BookID                                              Title  \
# 5650   20957  Colossians and Philemon: A Critical and Exeget...
# 1243    4287    Middlesex Borough Images of America: New Jersey
# 5649   20954                                Winchester Shotguns
# 6778   25426  Delwau Duon: Peintiadau Nicholas Evans = Symph...
# 4935   17830  Bulgakov's the Master and Margarita: The Text ...
# 9897   39829  His Princess Devotional: A Royal Encounter Wit...
# 9286   36492  Oliver Wendell Holmes in Paris: Medicine  Theo...
# 786     2560                  Willem de Kooning: Late Paintings
# 4126   14741  Zone of the Enders: The 2nd Runner Official St...
# 9851   39580  The American Campaign: U.S. Presidential Campa...
#
#                                    Authors average_rating        isbn  \
# 5650                        R. McL. Wilson              5   567044718
# 1243  Middlesex Borough Heritage Committee              5   738511676
# ...
